# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshudalkar/Data_Science/blob/main/Student_performance_descriptive_states_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #Creating Dataset & MetaData

# %%
student = pd.read_csv('/content/StudentsPerformance.csv')

# %%
student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
student.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
student.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#         'test preparation course', 'math score', 'reading score',
#         'writing score'],
#        dtype='object')]

# %%
student.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
student.size
# Out:
# 8000

# %%
student.shape
# Out:
# (1000, 8)

# %%
student.values
# Out:
# array([['female', 'group B', "bachelor's degree", ..., 72, 72, 74],
#        ['female', 'group C', 'some college', ..., 69, 90, 88],
#        ['female', 'group B', "master's degree", ..., 90, 95, 93],
#        ...,
#        ['female', 'group C', 'high school', ..., 59, 71, 65],
#        ['female', 'group D', 'some college', ..., 68, 78, 77],
#        ['female', 'group D', 'some college', ..., 77, 86, 86]],
#       dtype=object)

# %%
student.empty
# Out:
# False

# %%
student.ndim
# Out:
# 2

# %%
df = pd.DataFrame(student)
df.T
# Out:
#                                            0             1                2    \
# gender                                  female        female           female
# race/ethnicity                         group B       group C          group B
# parental level of education  bachelor's degree  some college  master's degree
# lunch                                 standard      standard         standard
# test preparation course                   none     completed             none
# math score                                  72            69               90
# reading score                               72            90               95
# writing score                               74            88               93
#
#                                             3             4    \
# gender                                     male          male
# race/ethnicity                          group A       group C
# parental level of education  associate's degree  some college
# ...

# %%
# student.count(0)
student.count(axis = 'index')
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
# student.count(1)
student.count(axis = 'columns')
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 995    8
# 996    8
# 997    8
# 998    8
# 999    8
# Length: 1000, dtype: int64

# %%
student[['test preparation course' , 'math score' , 'reading score' , 'writing score']]
# Out:
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 4 columns]

# %%
student.iat[10 , 5]
# Out:
# np.int64(58)

# %%
student.at[10 , 'lunch']
# Out:
# 'standard'

# %%
student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student.groupby('gender').mean(numeric_only=True)
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
student[student['math score'] > 60]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student['math score'][5]
# Out:
# np.int64(71)

# %%
student['math score'][5] = 72
# Out:
# <ipython-input-48-efa118e16b42>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   student['math score'][5] = 72
# <ipython-input-48-efa118e16b42>:1: SettingWithCopyWarning:
# ...

# %%
student['math score'][5]
student['math score'][5] = 71
student['math score'][5]
# Out:
# <ipython-input-50-d14d58f174f6>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   student['math score'][5] = 71
# <ipython-input-50-d14d58f174f6>:2: SettingWithCopyWarning:
# ...

# %% [markdown]
# #Descriptive statistics

# %%
student.max(axis=0 , skipna=True , numeric_only=True)
# Out:
# math score       100
# reading score    100
# writing score    100
# dtype: int64

# %%
student.min(axis=0 , skipna=False , numeric_only=True)
# Out:
# math score        0
# reading score    17
# writing score    10
# dtype: int64

# %%
student.idxmax()
# Out:
# gender                           3
# race/ethnicity                  32
# parental level of education     15
# lunch                            0
# test preparation course          0
# math score                     149
# reading score                  106
# writing score                  106
# dtype: int64

# %%
student.idxmin()
# Out:
# gender                          0
# race/ethnicity                  3
# parental level of education     3
# lunch                           3
# test preparation course         1
# math score                     59
# reading score                  59
# writing score                  59
# dtype: int64

# %%
student.mean(axis=0 , skipna=True , numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
student.mean(axis=1 , skipna=True , numeric_only=True)
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Length: 1000, dtype: float64

# %%
student.mean(axis=None , skipna=True , numeric_only=True)
# Out:
# np.float64(67.77066666666667)

# %%
student.mode(numeric_only=True)
# Out:
#    math score  reading score  writing score
# 0          65             72             74

# %%
student.median(numeric_only=True)
# Out:
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64

# %%
student.quantile(q = 0.5,numeric_only=True)
# Out:
# math score       66.0
# reading score    70.0
# writing score    69.0
# Name: 0.5, dtype: float64

# %%
student.std(numeric_only=True , skipna=True , axis=0)
# Out:
# math score       15.163080
# reading score    14.600192
# writing score    15.195657
# dtype: float64

# %%
student.var(numeric_only=True , skipna=True , axis=0)
# Out:
# math score       229.918998
# reading score    213.165605
# writing score    230.907992
# dtype: float64

# %%
student.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student.iloc[:,[5,6,7]].mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
student.sort_values(by=['math score'] , kind = 'quicksort' , inplace = False , ascending = True , na_position = 'first')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student.aggregate('mean' , numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df1 = student.groupby('gender')

# %%
df1.groups
# Out:
# {'female': [0, 1, 2, 5, 6, 9, 12, 14, 15, 17, 19, 21, 23, 27, 29, 30, 31, 32, 36, 37, 38, 41, 42, 44, 46, 47, 48, 54, 55, 56, 59, 63, 64, 67, 69, 70, 72, 78, 79, 80, 85, 86, 87, 88, 89, 90, 94, 97, 98, 99, 102, 105, 106, 108, 109, 110, 113, 114, 116, 117, 118, 119, 120, 122, 125, 129, 133, 138, 140, 141, 142, 145, 148, 152, 155, 156, 158, 161, 164, 165, 167, 168, 169, 172, 173, 174, 175, 176, 177, 178, 179, 181, 182, 183, 189, 190, 192, 194, 198, 199, ...], 'male': [3, 4, 7, 8, 10, 11, 13, 16, 18, 20, 22, 24, 25, 26, 28, 33, 34, 35, 39, 40, 43, 45, 49, 50, 51, 52, 53, 57, 58, 60, 61, 62, 65, 66, 68, 71, 73, 74, 75, 76, 77, 81, 82, 83, 84, 91, 92, 93, 95, 96, 100, 101, 103, 104, 107, 111, 112, 115, 121, 123, 124, 126, 127, 128, 130, 131, 132, 134, 135, 136, 137, 139, 143, 144, 146, 147, 149, 150, 151, 153, 154, 157, 159, 160, 162, 163, 166, 170, 171, 180, 184, 185, 186, 187, 188, 191, 193, 195, 196, 197, ...]}

# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshudalkar/Python_Pandas/blob/main/DataScience_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Pandas**

# %%
import pandas as pd

# %%
#Read csv file
df = pd.read_csv("/content/Salaries.csv")

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
print("Maximum salary is" , df.salary.max())
# Out:
# Maximum salary is 186960

# %%
print("Maximum salary is" , df.salary.min())
# Out:
# Maximum salary is 57800

# %%
df.head(51)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
print("Maximum salary is" , df.sort_values(by = 'salary'))
# Out:
# Maximum salary is          rank discipline  phd  service     sex  salary
# 9        Prof          A   51       51    Male   57800
# 54  AssocProf          A   25       22  Female   62884
# 66   AsstProf          A    7        6  Female   63100
# 71  AssocProf          B   12        9  Female   71065
# 55   AsstProf          A    2        0  Female   72500
# ..        ...        ...  ...      ...     ...     ...
# 31       Prof          B   22       21    Male  155750
# 27       Prof          A   45       43    Male  155865
# 72       Prof          B   24       15  Female  161101
# 13       Prof          B   35       33    Male  162200
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.size
# Out:
# 468

# %%
df.iloc[40]
# Out:
# rank            Prof
# discipline         A
# phd               39
# service           36
# sex           Female
# salary        137000
# Name: 40, dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
num = len(df)
print(num)
print(len(df))
# Out:
# 78
# 78

# %%
num_rows = df.shape[0]
print(num_rows)
# Out:
# 78

# %%
df.salary.describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
df.head(5)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
print(len(df))
# Out:
# 78

# %%
df1 = df.sample(50)

# %%
df1
# Out:
#          rank discipline  phd  service     sex  salary
# 13       Prof          B   35       33    Male  162200
# 70   AsstProf          A    8        3  Female   78500
# 15       Prof          B   17        3    Male  150480
# 55   AsstProf          A    2        0  Female   72500
# 51       Prof          B   20       14  Female  127512
# 77       Prof          A   23       15  Female  109646
# 18       Prof          A   19        7    Male  107300
# 76       Prof          A   28       14  Female  109954
# 32       Prof          A   27       19    Male  103275
# 3        Prof          A   40       31    Male  131205
# 29       Prof          B   21       20    Male  123683
# 56  AssocProf          A   10        8  Female   77500
# 72       Prof          B   24       15  Female  161101
# 45       Prof          B   25       25  Female  140096
# 9        Prof          A   51       51    Male   57800
# 37       Prof          A   20        8    Male  102000
# ...

# %%
df1.describe()
# Out:
#              phd    service         salary
# count  50.000000  50.000000      50.000000
# mean   21.040000  16.160000  108850.120000
# std    12.407963  12.469326   29688.522697
# min     2.000000   0.000000   57800.000000
# 25%    12.000000   6.250000   82213.750000
# 50%    20.500000  16.000000  106150.000000
# 75%    28.000000  22.750000  130653.750000
# max    51.000000  51.000000  162200.000000

# %%
df.salary.std()
df.select_dtypes(include=['number']).std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df2 = df.head(50)
#df2.select_dtypes(include = ['number']).mean()
#same as above
df2.mean(numeric_only=True)
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df.phd.head(50).describe()
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.count()
# Out:
# np.int64(78)

# %%
print(df.phd.mean())
# Out:
# 19.705128205128204

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df_rank = df.groupby(['rank'])

# %%
df_rank.mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df_rank.describe()
# Out:
#             phd                                                      service  \
#           count       mean        std   min    25%   50%   75%   max   count
# rank
# AssocProf  13.0  15.076923   5.589597   9.0  12.00  13.0  19.0  26.0    13.0
# AsstProf   19.0   5.052632   2.738079   1.0   3.50   4.0   7.0  11.0    19.0
# Prof       46.0  27.065217  10.185834  12.0  19.25  24.5  34.5  56.0    46.0
#
#                       ...              salary                               \
#                 mean  ...    75%   max  count           mean           std
# rank                  ...
# AssocProf  11.307692  ...  11.00  24.0   13.0   91786.230769  18571.183714
# AsstProf    2.210526  ...   3.00   6.0   19.0   81362.789474   9381.245301
# Prof       21.413043  ...  26.75  51.0   46.0  123624.804348  24850.287853
#
#
#                min       25%       50%        75%       max
# rank
# AssocProf  62884.0   74830.0  103613.0  104542.00  119800.0
# ...

# %%
df.groupby(['sex']).mean(numeric_only=True)
# Out:
#               phd    service         salary
# sex
# Female  16.512821  11.564103  101002.410256
# Male    22.897436  18.538462  115045.153846

# %%
df[df.salary > 120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df[df['salary'] <= 120000]
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# ...

# %%
newDf = df[['salary','rank']]
print(df.iloc[:,2])
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.iloc[0:,[1,3]]
# Out:
#    discipline  service
# 0           B       49
# 1           A        6
# 2           A       20
# 3           A       31
# 4           B       18
# ..        ...      ...
# 73          B       10
# 74          B        6
# 75          B       17
# 76          A       14
# 77          A       15
#
# [78 rows x 2 columns]

# %%
df.iloc[0:10, 1:4]
# Out:
#   discipline  phd  service
# 0          B   56       49
# 1          A   12        6
# 2          A   23       20
# 3          A   40       31
# 4          B   20       18
# 5          A   20       20
# 6          A   20       17
# 7          A   18       18
# 8          A   29       19
# 9          A   51       51

# %%
df.iloc[:,5:]
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
df.iloc[[59,] ,]
# Out:
#          rank discipline  phd  service     sex  salary
# 59  AssocProf          B   12       10  Female  103994

# %%
df.iloc[[0,2] ,]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 2  Prof          A   23       20  Male  110515

# %%
df[["phd" , "salary"]].agg(['min' , 'max' , 'mean'])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# max   56.000000  186960.000000
# mean  19.705128  108023.782051

# %%
df.salary.var(ddof = 0)
df.salary.skew(numeric_only=True)
# Out:
# np.float64(0.45210256755588096)
